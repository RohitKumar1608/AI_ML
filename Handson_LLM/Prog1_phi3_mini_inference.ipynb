# %% [markdown]
# <a href="https://colab.research.google.com/github/RohitKumar1608/AI_ML/blob/main/Prog1_phi3_mini_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install -U transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3-mini-4k-instruct",torch_dtype="auto",)
# Out:
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]

# %%
print(type(model))
print(model.config.model_type)
print(f"Parameters: {sum(p.numel() for p in model.parameters()) / 1e9:.1f}B")

# Check tokenizer is loaded
print(type(tokenizer))
print(tokenizer.vocab_size)
# Out:
# <class 'transformers.models.phi3.modeling_phi3.Phi3ForCausalLM'>
# phi3
# Parameters: 3.8B
# <class 'transformers.tokenization_utils_tokenizers.TokenizersBackend'>
# 32000

# %%
# Create pipeline without generation args
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False
)

# Pass generation args when calling it
messages = [
    {"role": "user", "content": "Who won the FIFA World Cup 2026?"}
]
output = generator(messages, max_new_tokens=500, do_sample=False)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...
